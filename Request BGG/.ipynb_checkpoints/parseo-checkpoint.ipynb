# %%
conda install -c conda-forge scrapy
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - scrapy
#
#
# The following NEW packages will be INSTALLED:
#
#   automat            conda-forge/noarch::automat-0.8.0-py_0
#   bcrypt             conda-forge/win-64::bcrypt-3.1.7-py37hfa6e2cd_0
#   constantly         conda-forge/noarch::constantly-15.1.0-py_0
#   cssselect          conda-forge/noarch::cssselect-1.1.0-py_0
#   hyperlink          conda-forge/noarch::hyperlink-17.3.1-py_0
#   incremental        conda-forge/noarch::incremental-17.5.0-py_0
#   parsel             pkgs/main/win-64::parsel-1.5.2-py37_0
#   pyasn1             conda-forge/noarch::pyasn1-0.4.8-py_0
#   pyasn1-modules     conda-forge/noarch::pyasn1-modules-0.2.7-py_0
#   pydispatcher       conda-forge/noarch::pydispatcher-2.0.5-py_1
#   pyhamcrest         conda-forge/noarch::pyhamcrest-1.9.0-py_2
#   pytest-runner      conda-forge/noarch::pytest-runner-5.2-py_0
# ...

# %%
conda update -n base -c defaults conda
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - conda
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     automat-0.8.0              |             py_0          32 KB
#     bcrypt-3.1.7               |   py37he774522_0          38 KB
#     constantly-15.1.0          |   py37h28b3542_0          13 KB
#     cssselect-1.1.0            |             py_0          18 KB
#     hyperlink-19.0.0           |             py_0          36 KB
#     incremental-17.5.0         |           py37_0          25 KB
#     pyasn1-0.4.8               |             py_0          58 KB
#     pyasn1-modules-0.2.7       |             py_0          63 KB
#     pydispatcher-2.0.5         |           py37_1          19 KB
#     pyhamcrest-1.9.0           |           py37_2          48 KB
# ...

# %%
import requests
r = requests.get('https://boardgamegeek.com/browse/boardgame')
print(r.text)
# Out:
# <!DOCTYPE html>
# <html ng-app="GeekApp" lang="en-US" ng-cloak>
# <head>
# 	<meta charset='utf-8'>
# 	<meta id="vp" name="viewport" content="width=device-width, initial-scale=1.0">
# 			<script>
# 			window.addEventListener( 'DOMContentLoaded',  function() {
# 				if (window.innerWidth < 960) {
# 					var mvp = document.getElementById('vp');
# 					mvp.setAttribute('content','width=960');
# 				}
# 			});
# 		</script>
# 		<meta content='yes' name='apple-mobile-web-app-capable'>
# 	<meta content='IE=edge,chrome=1' http-equiv='X-UA-Compatible'>
#
# 			<title>Browse Board Games | BoardGameGeek</title>
#
#
# <link rel="apple-touch-icon" 	href="https://cf.geekdo-static.com/icons/touch-icon180.png" />
# <link rel="shortcut icon" 		href="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />
# <link rel="icon" 					href="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />
# ...

# %%
xpath_gloom='/html/body/div[2]/main/div/div[1]/div[1]/div/div/div[2]/div[3]/table/tbody/tr[2]/td[3]/div[2]/a'

# %%
xpath_gloom
# Out:
# '/html/body/div[2]/main/div/div[1]/div[1]/div/div/div[2]/div[3]/table/tbody/tr[2]/td[3]/div[2]/a'

# %%
import lmxl
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-715bf856d289> in <module>
# ----> 1 import lmxl
#
# ModuleNotFoundError: No module named 'lmxl'

# %%
import lxml

# %%
htmlparser = lxml.etree.HTMLParser()
html_tree = etree.parse(r.text, htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c0c3efaae465> in <module>
# ----> 1 htmlparser = lxml.etree.HTMLParser()
#       2 html_tree = etree.parse(r.text, htmlparser)
#       3 print(html_tree.xpath(xpath_gloom))
#
# AttributeError: module 'lxml' has no attribute 'etree'

# %%
htmlparser = lxml.etree.HTMLParser()
html_tree = lxml.etree.parse(r.text, htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-0e6c7945b7d2> in <module>
# ----> 1 htmlparser = lxml.etree.HTMLParser()
#       2 html_tree = lxml.etree.parse(r.text, htmlparser)
#       3 print(html_tree.xpath(xpath_gloom))
#
# AttributeError: module 'lxml' has no attribute 'etree'

# %%
from lxml import etree

# %%
htmlparser = lxml.etree.HTMLParser()
html_tree = lxml.etree.parse(r.text, htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-9-0e6c7945b7d2> in <module>
#       1 htmlparser = lxml.etree.HTMLParser()
# ----> 2 html_tree = lxml.etree.parse(r.text, htmlparser)
#       3 print(html_tree.xpath(xpath_gloom))
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# src/lxml/parser.pxi in lxml.etree._parseDocumentFromURL()
#
# src/lxml/parser.pxi in lxml.etree._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._BaseParser._parseDocFromFile()
#
# src/lxml/parser.pxi in lxml.etree._ParserContext._handleParseResultDoc()
#
# src/lxml/parser.pxi in lxml.etree._handleParseResult()
#
# src/lxml/parser.pxi in lxml.etree._raiseParseError()
#
# OSError: Error reading file '
# <!DOCTYPE html>
# <html ng-app="GeekApp" lang="en-US" ng-cloak>
# <head>
# 	<meta charset='utf-8'>
# ...

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(r, htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-5ff88cccc746> in <module>
#       1 htmlparser = etree.HTMLParser()
# ----> 2 html_tree = etree.parse(r, htmlparser)
#       3 print(html_tree.xpath(xpath_gloom))
#
# src/lxml/etree.pyx in lxml.etree.parse()
#
# src/lxml/parser.pxi in lxml.etree._parseDocument()
#
# TypeError: cannot parse from 'Response'

# %%
import StringIO
from lxml import etree

htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-f0180071b077> in <module>
# ----> 1 import StringIO
#       2 from lxml import etree
#       3
#       4 htmlparser = etree.HTMLParser()
#       5 html_tree = etree.parse(StringIO(r.text), htmlparser)
#
# ModuleNotFoundError: No module named 'StringIO'

# %%
import stringIO
from lxml import etree

htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-12-1b71c0b1bd1d> in <module>
# ----> 1 import stringIO
#       2 from lxml import etree
#       3
#       4 htmlparser = etree.HTMLParser()
#       5 html_tree = etree.parse(StringIO(r.text), htmlparser)
#
# ModuleNotFoundError: No module named 'stringIO'

# %%
import StrigIO
from lxml import etree

htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-2df59e140951> in <module>
# ----> 1 import StrigIO
#       2 from lxml import etree
#       3
#       4 htmlparser = etree.HTMLParser()
#       5 html_tree = etree.parse(StringIO(r.text), htmlparser)
#
# ModuleNotFoundError: No module named 'StrigIO'

# %%
from io import StringIO 
from lxml import etree

htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_gloom))
# Out:
# []

# %%
XPATH_TABLE = '//table[@id="collectionitems"]'

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(XPATH_TABLE))
# Out:
# [<Element table at 0x18705003e88>]

# %%
xpath_row = '//table[@id="collectionitems"]/tr'

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_row))
# Out:
# [<Element tr at 0x1870500d8c8>, <Element tr at 0x1870500d908>, <Element tr at 0x1870500d148>, <Element tr at 0x1870500da08>, <Element tr at 0x1870500da48>, <Element tr at 0x1870500dac8>, <Element tr at 0x1870500db08>, <Element tr at 0x1870500db48>, <Element tr at 0x1870500db88>, <Element tr at 0x1870500da88>, <Element tr at 0x1870500dbc8>, <Element tr at 0x1870500dc08>, <Element tr at 0x1870500dc48>, <Element tr at 0x1870500dc88>, <Element tr at 0x1870500dcc8>, <Element tr at 0x1870500dd08>, <Element tr at 0x1870500dd48>, <Element tr at 0x1870500dd88>, <Element tr at 0x1870500ddc8>, <Element tr at 0x1870500de08>, <Element tr at 0x1870500de48>, <Element tr at 0x1870500de88>, <Element tr at 0x1870500dec8>, <Element tr at 0x1870500df08>, <Element tr at 0x1870500df48>, <Element tr at 0x1870500df88>, <Element tr at 0x1870500dfc8>, <Element tr at 0x1870500f048>, <Element tr at 0x1870500f088>, <Element tr at 0x1870500f0c8>, <Element tr at 0x1870500f108>, <Element tr at 0x1870500f148>, <Elem
# ...

# %%
xpath_cell = "//table[@id='collectionitems']/tr/td[contains(@class,'collection_objectname')]"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_cell))
# Out:
# [<Element td at 0x18705011408>, <Element td at 0x18705011448>, <Element td at 0x18705011508>, <Element td at 0x18705011548>, <Element td at 0x18705011588>, <Element td at 0x18705011608>, <Element td at 0x18705011648>, <Element td at 0x18705011688>, <Element td at 0x187050116c8>, <Element td at 0x187050115c8>, <Element td at 0x18705011708>, <Element td at 0x18705011748>, <Element td at 0x18705011788>, <Element td at 0x187050117c8>, <Element td at 0x18705011808>, <Element td at 0x18705011848>, <Element td at 0x18705011888>, <Element td at 0x187050118c8>, <Element td at 0x18705011908>, <Element td at 0x18705011948>, <Element td at 0x18705011988>, <Element td at 0x187050119c8>, <Element td at 0x18705011a08>, <Element td at 0x18705011a48>, <Element td at 0x18705011a88>, <Element td at 0x18705011ac8>, <Element td at 0x18705011b08>, <Element td at 0x18705011b48>, <Element td at 0x18705011b88>, <Element td at 0x18705011bc8>, <Element td at 0x18705011c08>, <Element td at 0x18705011c48>, <Elem
# ...

# %%
xpath_name = "//table[@id='collectionitems']/tr/td[contains(@class,'collection_objectname')]/div[2]/a"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_name))
# Out:
# [<Element a at 0x18705d4c808>, <Element a at 0x18705d4c748>, <Element a at 0x18705d4c7c8>, <Element a at 0x18705d4c848>, <Element a at 0x18705d4c888>, <Element a at 0x18705d4c908>, <Element a at 0x18705d4c948>, <Element a at 0x18705d4c988>, <Element a at 0x18705d4c9c8>, <Element a at 0x18705d4c8c8>, <Element a at 0x18705d4ca08>, <Element a at 0x18705d4ca48>, <Element a at 0x18705d4ca88>, <Element a at 0x18705d4cac8>, <Element a at 0x18705d4cb08>, <Element a at 0x18705d4cb48>, <Element a at 0x18705d4cb88>, <Element a at 0x18705d4cbc8>, <Element a at 0x18705d4cc08>, <Element a at 0x18705d4cc48>, <Element a at 0x18705d4cc88>, <Element a at 0x18705d4ccc8>, <Element a at 0x18705d4cd08>, <Element a at 0x18705d4cd48>, <Element a at 0x18705d4cd88>, <Element a at 0x18705d4cdc8>, <Element a at 0x18705d4ce08>, <Element a at 0x18705d4ce48>, <Element a at 0x18705d4ce88>, <Element a at 0x18705d4cec8>, <Element a at 0x18705d4cf08>, <Element a at 0x18705d4cf48>, <Element a at 0x18705d4cf88>, <Elemen
# ...

# %%
xpath = "//table[@id='collectionitems']/tr/td[contains(@class,'collection_objectname')]/div[2]/a/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath)
# Out:
#   File "<ipython-input-26-3e6f8e6edbb3>", line 3
#     print(html_tree.xpath(xpath)
#                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath))
# Out:
# ['Gloomhaven', 'Pandemic Legacy: Season 1', 'Terraforming Mars', 'Through the Ages: A New Story of Civilization', 'Brass: Birmingham', 'Twilight Imperium (Fourth Edition)', 'Twilight Struggle', 'Star Wars: Rebellion', 'Gaia Project', 'Scythe', 'Great Western Trail', 'War of the Ring (Second Edition)', 'Spirit Island', 'Terra Mystica', 'The Castles of Burgundy', '7 Wonders Duel', 'The 7th Continent', 'Concordia', 'Brass: Lancashire', 'Viticulture Essential Edition', 'Arkham Horror: The Card Game', 'Puerto Rico', 'A Feast for Odin', 'Mage Knight Board Game', 'Orléans', 'Wingspan', 'Caverna: The Cave Farmers', 'Food Chain Magnate', 'Agricola', 'Mansions of Madness: Second Edition', 'Blood Rage', 'Kingdom Death: Monster', 'Pandemic Legacy: Season 2', 'Power Grid', 'Mechs vs. Minions', 'Through the Ages: A Story of Civilization', 'Star Wars: Imperial Assault', "Tzolk'in: The Mayan Calendar", 'Root', 'Eclipse', 'Azul', 'Le Havre', 'Nemesis', 'Clans of Caledonia', 'The Voyages of Marco Polo
# ...

# %%
xpath_name = "//table[@id='collectionitems']/tr/td[3]/div[2]/a/text()"
xpath_year = "//table[@id='collectionitems']/tr/td[3]/div[2]/span/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[4]/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[5]/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[6]/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[7]/div[3]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_geek))
# Out:
# []

# %%
xpath_name = "//table[@id='collectionitems']/tr/td[3]/div[2]/a/text()"
xpath_year = "//table[@id='collectionitems']/tr/td[3]/div[2]/span/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[4]/text()"
xpath_av = "//table[@id='collectionitems']/tr/td[5]/text()"
xpath_voters = "//table[@id='collectionitems']/tr/td[6]/text()"
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[1]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_name))
# Out:
# ['Gloomhaven', 'Pandemic Legacy: Season 1', 'Terraforming Mars', 'Through the Ages: A New Story of Civilization', 'Brass: Birmingham', 'Twilight Imperium (Fourth Edition)', 'Twilight Struggle', 'Star Wars: Rebellion', 'Gaia Project', 'Scythe', 'Great Western Trail', 'War of the Ring (Second Edition)', 'Spirit Island', 'Terra Mystica', 'The Castles of Burgundy', '7 Wonders Duel', 'The 7th Continent', 'Concordia', 'Brass: Lancashire', 'Viticulture Essential Edition', 'Arkham Horror: The Card Game', 'Puerto Rico', 'A Feast for Odin', 'Mage Knight Board Game', 'Orléans', 'Wingspan', 'Caverna: The Cave Farmers', 'Food Chain Magnate', 'Agricola', 'Mansions of Madness: Second Edition', 'Blood Rage', 'Kingdom Death: Monster', 'Pandemic Legacy: Season 2', 'Power Grid', 'Mechs vs. Minions', 'Through the Ages: A Story of Civilization', 'Star Wars: Imperial Assault', "Tzolk'in: The Mayan Calendar", 'Root', 'Eclipse', 'Azul', 'Le Havre', 'Nemesis', 'Clans of Caledonia', 'The Voyages of Marco Polo
# ...

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_geek))
# Out:
# ['\n\t\t\t8.585\t\t', '\n\t\t\t8.471\t\t', '\n\t\t\t8.269\t\t', '\n\t\t\t8.236\t\t', '\n\t\t\t8.213\t\t', '\n\t\t\t8.174\t\t', '\n\t\t\t8.160\t\t', '\n\t\t\t8.156\t\t', '\n\t\t\t8.140\t\t', '\n\t\t\t8.098\t\t', '\n\t\t\t8.097\t\t', '\n\t\t\t8.064\t\t', '\n\t\t\t8.033\t\t', '\n\t\t\t8.021\t\t', '\n\t\t\t8.011\t\t', '\n\t\t\t7.979\t\t', '\n\t\t\t7.969\t\t', '\n\t\t\t7.945\t\t', '\n\t\t\t7.937\t\t', '\n\t\t\t7.922\t\t', '\n\t\t\t7.916\t\t', '\n\t\t\t7.901\t\t', '\n\t\t\t7.896\t\t', '\n\t\t\t7.891\t\t', '\n\t\t\t7.882\t\t', '\n\t\t\t7.881\t\t', '\n\t\t\t7.878\t\t', '\n\t\t\t7.869\t\t', '\n\t\t\t7.867\t\t', '\n\t\t\t7.855\t\t', '\n\t\t\t7.825\t\t', '\n\t\t\t7.818\t\t', '\n\t\t\t7.812\t\t', '\n\t\t\t7.786\t\t', '\n\t\t\t7.782\t\t', '\n\t\t\t7.773\t\t', '\n\t\t\t7.772\t\t', '\n\t\t\t7.770\t\t', '\n\t\t\t7.766\t\t', '\n\t\t\t7.748\t\t', '\n\t\t\t7.738\t\t', '\n\t\t\t7.737\t\t', '\n\t\t\t7.729\t\t', '\n\t\t\t7.723\t\t', '\n\t\t\t7.719\t\t', '\n\t\t\t7.714\t\t', '\n\t\t\t7.692\t\t', '\n\t\t\t7
# ...

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_voters))
# Out:
# ['\n\t\t\t31656\t\t', '\n\t\t\t34912\t\t', '\n\t\t\t48903\t\t', '\n\t\t\t18408\t\t', '\n\t\t\t10297\t\t', '\n\t\t\t9532\t\t', '\n\t\t\t36772\t\t', '\n\t\t\t19125\t\t', '\n\t\t\t12166\t\t', '\n\t\t\t46928\t\t', '\n\t\t\t23320\t\t', '\n\t\t\t11259\t\t', '\n\t\t\t16505\t\t', '\n\t\t\t35087\t\t', '\n\t\t\t40382\t\t', '\n\t\t\t47442\t\t', '\n\t\t\t12969\t\t', '\n\t\t\t23070\t\t', '\n\t\t\t16751\t\t', '\n\t\t\t21868\t\t', '\n\t\t\t21334\t\t', '\n\t\t\t58972\t\t', '\n\t\t\t13638\t\t', '\n\t\t\t25195\t\t', '\n\t\t\t18240\t\t', '\n\t\t\t21998\t\t', '\n\t\t\t25506\t\t', '\n\t\t\t11496\t\t', '\n\t\t\t59596\t\t', '\n\t\t\t19924\t\t', '\n\t\t\t28877\t\t', '\n\t\t\t6661\t\t', '\n\t\t\t9079\t\t', '\n\t\t\t52471\t\t', '\n\t\t\t12322\t\t', '\n\t\t\t17315\t\t', '\n\t\t\t18227\t\t', '\n\t\t\t26743\t\t', '\n\t\t\t14177\t\t', '\n\t\t\t24905\t\t', '\n\t\t\t38629\t\t', '\n\t\t\t24332\t\t', '\n\t\t\t6469\t\t', '\n\t\t\t11307\t\t', '\n\t\t\t17271\t\t', '\n\t\t\t29525\t\t', '\n\t\t\t25301\t\t', '\n\t\t\t8884\
# ...

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[3]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[2]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# ['\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n', '\n\t', '\n']

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[2]/div[1]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[3]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[1]/div[1]/div[1]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[1]/div[1]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_price = "//table[@id='collectionitems']/tr/td[7]/div[contains(@class,'aad')]/div[1]/div[1]/text()"

# %%
htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)
print(html_tree.xpath(xpath_price))
# Out:
# []

# %%
xpath_name = "//table[@id='collectionitems']/tr/td[3]/div[2]/a/text()"
xpath_year = "//table[@id='collectionitems']/tr/td[3]/div[2]/span/text()"
xpath_geek = "//table[@id='collectionitems']/tr/td[4]/text()"
xpath_av = "//table[@id='collectionitems']/tr/td[5]/text()"
xpath_voters = "//table[@id='collectionitems']/tr/td[6]/text()"

htmlparser = etree.HTMLParser()
html_tree = etree.parse(StringIO(r.text), htmlparser)

name = html_tree.xpath(xpath_name)
year= html_tree.xpath(xpath_year)
geek = html_tree.xpath(xpath_geek)
av = html_tree.xpath(xpath_av)
voters = html_tree.xpath(xpath_voters)

# %%
print(name)
# Out:
# ['Gloomhaven', 'Pandemic Legacy: Season 1', 'Terraforming Mars', 'Through the Ages: A New Story of Civilization', 'Brass: Birmingham', 'Twilight Imperium (Fourth Edition)', 'Twilight Struggle', 'Star Wars: Rebellion', 'Gaia Project', 'Scythe', 'Great Western Trail', 'War of the Ring (Second Edition)', 'Spirit Island', 'Terra Mystica', 'The Castles of Burgundy', '7 Wonders Duel', 'The 7th Continent', 'Concordia', 'Brass: Lancashire', 'Viticulture Essential Edition', 'Arkham Horror: The Card Game', 'Puerto Rico', 'A Feast for Odin', 'Mage Knight Board Game', 'Orléans', 'Wingspan', 'Caverna: The Cave Farmers', 'Food Chain Magnate', 'Agricola', 'Mansions of Madness: Second Edition', 'Blood Rage', 'Kingdom Death: Monster', 'Pandemic Legacy: Season 2', 'Power Grid', 'Mechs vs. Minions', 'Through the Ages: A Story of Civilization', 'Star Wars: Imperial Assault', "Tzolk'in: The Mayan Calendar", 'Root', 'Eclipse', 'Azul', 'Le Havre', 'Nemesis', 'Clans of Caledonia', 'The Voyages of Marco Polo
# ...

# %%
print(voters)
# Out:
# ['\n\t\t\t31656\t\t', '\n\t\t\t34912\t\t', '\n\t\t\t48903\t\t', '\n\t\t\t18408\t\t', '\n\t\t\t10297\t\t', '\n\t\t\t9532\t\t', '\n\t\t\t36772\t\t', '\n\t\t\t19125\t\t', '\n\t\t\t12166\t\t', '\n\t\t\t46928\t\t', '\n\t\t\t23320\t\t', '\n\t\t\t11259\t\t', '\n\t\t\t16505\t\t', '\n\t\t\t35087\t\t', '\n\t\t\t40382\t\t', '\n\t\t\t47442\t\t', '\n\t\t\t12969\t\t', '\n\t\t\t23070\t\t', '\n\t\t\t16751\t\t', '\n\t\t\t21868\t\t', '\n\t\t\t21334\t\t', '\n\t\t\t58972\t\t', '\n\t\t\t13638\t\t', '\n\t\t\t25195\t\t', '\n\t\t\t18240\t\t', '\n\t\t\t21998\t\t', '\n\t\t\t25506\t\t', '\n\t\t\t11496\t\t', '\n\t\t\t59596\t\t', '\n\t\t\t19924\t\t', '\n\t\t\t28877\t\t', '\n\t\t\t6661\t\t', '\n\t\t\t9079\t\t', '\n\t\t\t52471\t\t', '\n\t\t\t12322\t\t', '\n\t\t\t17315\t\t', '\n\t\t\t18227\t\t', '\n\t\t\t26743\t\t', '\n\t\t\t14177\t\t', '\n\t\t\t24905\t\t', '\n\t\t\t38629\t\t', '\n\t\t\t24332\t\t', '\n\t\t\t6469\t\t', '\n\t\t\t11307\t\t', '\n\t\t\t17271\t\t', '\n\t\t\t29525\t\t', '\n\t\t\t25301\t\t', '\n\t\t\t8884\
# ...

# %%
print

# %%
print(tabla)

# %%
print(list(tabla))
# Out:
# [('Gloomhaven', '(2017)', '\n\t\t\t8.585\t\t', '\n\t\t\t8.85\t\t', '\n\t\t\t31656\t\t'), ('Pandemic Legacy: Season 1', '(2015)', '\n\t\t\t8.471\t\t', '\n\t\t\t8.62\t\t', '\n\t\t\t34912\t\t'), ('Terraforming Mars', '(2016)', '\n\t\t\t8.269\t\t', '\n\t\t\t8.42\t\t', '\n\t\t\t48903\t\t'), ('Through the Ages: A New Story of Civilization', '(2015)', '\n\t\t\t8.236\t\t', '\n\t\t\t8.49\t\t', '\n\t\t\t18408\t\t'), ('Brass: Birmingham', '(2018)', '\n\t\t\t8.213\t\t', '\n\t\t\t8.63\t\t', '\n\t\t\t10297\t\t'), ('Twilight Imperium (Fourth Edition)', '(2017)', '\n\t\t\t8.174\t\t', '\n\t\t\t8.69\t\t', '\n\t\t\t9532\t\t'), ('Twilight Struggle', '(2005)', '\n\t\t\t8.160\t\t', '\n\t\t\t8.31\t\t', '\n\t\t\t36772\t\t'), ('Star Wars: Rebellion', '(2016)', '\n\t\t\t8.156\t\t', '\n\t\t\t8.43\t\t', '\n\t\t\t19125\t\t'), ('Gaia Project', '(2017)', '\n\t\t\t8.140\t\t', '\n\t\t\t8.50\t\t', '\n\t\t\t12166\t\t'), ('Scythe', '(2016)', '\n\t\t\t8.098\t\t', '\n\t\t\t8.26\t\t', '\n\t\t\t46928\t\t'), ('Great Western
# ...

# %%
tabla = list(zip(name,year,geek,av,voters))

# %%
print(tabla)
# Out:
# [('Gloomhaven', '(2017)', '\n\t\t\t8.585\t\t', '\n\t\t\t8.85\t\t', '\n\t\t\t31656\t\t'), ('Pandemic Legacy: Season 1', '(2015)', '\n\t\t\t8.471\t\t', '\n\t\t\t8.62\t\t', '\n\t\t\t34912\t\t'), ('Terraforming Mars', '(2016)', '\n\t\t\t8.269\t\t', '\n\t\t\t8.42\t\t', '\n\t\t\t48903\t\t'), ('Through the Ages: A New Story of Civilization', '(2015)', '\n\t\t\t8.236\t\t', '\n\t\t\t8.49\t\t', '\n\t\t\t18408\t\t'), ('Brass: Birmingham', '(2018)', '\n\t\t\t8.213\t\t', '\n\t\t\t8.63\t\t', '\n\t\t\t10297\t\t'), ('Twilight Imperium (Fourth Edition)', '(2017)', '\n\t\t\t8.174\t\t', '\n\t\t\t8.69\t\t', '\n\t\t\t9532\t\t'), ('Twilight Struggle', '(2005)', '\n\t\t\t8.160\t\t', '\n\t\t\t8.31\t\t', '\n\t\t\t36772\t\t'), ('Star Wars: Rebellion', '(2016)', '\n\t\t\t8.156\t\t', '\n\t\t\t8.43\t\t', '\n\t\t\t19125\t\t'), ('Gaia Project', '(2017)', '\n\t\t\t8.140\t\t', '\n\t\t\t8.50\t\t', '\n\t\t\t12166\t\t'), ('Scythe', '(2016)', '\n\t\t\t8.098\t\t', '\n\t\t\t8.26\t\t', '\n\t\t\t46928\t\t'), ('Great Western
# ...

# %%
year_string = html_tree.xpath(xpath_year)
geek_string = html_tree.xpath(xpath_geek)
av_string = html_tree.xpath(xpath_av)
voters_string = html_tree.xpath(xpath_voters)

# %%
    def clean_year(year_string):
        replace('(','')
        replace(')','')
        return clean_year(year_string)

# %%
print(year_string)
# Out:
# ['(2017)', '(2015)', '(2016)', '(2015)', '(2018)', '(2017)', '(2005)', '(2016)', '(2017)', '(2016)', '(2016)', '(2012)', '(2017)', '(2012)', '(2011)', '(2015)', '(2017)', '(2013)', '(2007)', '(2015)', '(2016)', '(2002)', '(2016)', '(2011)', '(2014)', '(2019)', '(2013)', '(2015)', '(2007)', '(2016)', '(2015)', '(2015)', '(2017)', '(2004)', '(2016)', '(2006)', '(2014)', '(2012)', '(2018)', '(2011)', '(2017)', '(2008)', '(2018)', '(2017)', '(2015)', '(2012)', '(2012)', '(2017)', '(2010)', '(2007)', '(2012)', '(2010)', '(2014)', '(2005)', '(2012)', '(2014)', '(2015)', '(2016)', '(2005)', '(1995)', '(2018)', '(2013)', '(2015)', '(2009)', '(2008)', '(2015)', '(2017)', '(2018)', '(2014)', '(2018)', '(2010)', '(1876)', '(2017)', '(2016)', '(2013)', '(2014)', '(1981)', '(1997)', '(2018)', '(2011)', '(2016)', '(2018)', '(2008)', '(2008)', '(2015)', '(2016)', '(2012)', '(2012)', '(2016)', '(2015)', '(2014)', '(2015)', '(2015)', '(2008)', '(2015)', '(2012)', '(2014)', '(2016)', '(2018)', '(2014)
# ...

# %%
def clean_year(year_string):
    year_string.replace('(','')
    year_string.replace(')','')
    return year = clean_year(year_sting)
# Out:
#   File "<ipython-input-64-02a5434e4caa>", line 4
#     return year = clean_year(year_sting)
#                 ^
# SyntaxError: invalid syntax

# %%
print(year)
# Out:
# ['(2017)', '(2015)', '(2016)', '(2015)', '(2018)', '(2017)', '(2005)', '(2016)', '(2017)', '(2016)', '(2016)', '(2012)', '(2017)', '(2012)', '(2011)', '(2015)', '(2017)', '(2013)', '(2007)', '(2015)', '(2016)', '(2002)', '(2016)', '(2011)', '(2014)', '(2019)', '(2013)', '(2015)', '(2007)', '(2016)', '(2015)', '(2015)', '(2017)', '(2004)', '(2016)', '(2006)', '(2014)', '(2012)', '(2018)', '(2011)', '(2017)', '(2008)', '(2018)', '(2017)', '(2015)', '(2012)', '(2012)', '(2017)', '(2010)', '(2007)', '(2012)', '(2010)', '(2014)', '(2005)', '(2012)', '(2014)', '(2015)', '(2016)', '(2005)', '(1995)', '(2018)', '(2013)', '(2015)', '(2009)', '(2008)', '(2015)', '(2017)', '(2018)', '(2014)', '(2018)', '(2010)', '(1876)', '(2017)', '(2016)', '(2013)', '(2014)', '(1981)', '(1997)', '(2018)', '(2011)', '(2016)', '(2018)', '(2008)', '(2008)', '(2015)', '(2016)', '(2012)', '(2012)', '(2016)', '(2015)', '(2014)', '(2015)', '(2015)', '(2008)', '(2015)', '(2012)', '(2014)', '(2016)', '(2018)', '(2014)
# ...

# %%
def clean_year(year_string):
    year_string.replace('(','')
    year_string.replace(')','')
    return year_string

# %%
print(year_string)
# Out:
# ['(2017)', '(2015)', '(2016)', '(2015)', '(2018)', '(2017)', '(2005)', '(2016)', '(2017)', '(2016)', '(2016)', '(2012)', '(2017)', '(2012)', '(2011)', '(2015)', '(2017)', '(2013)', '(2007)', '(2015)', '(2016)', '(2002)', '(2016)', '(2011)', '(2014)', '(2019)', '(2013)', '(2015)', '(2007)', '(2016)', '(2015)', '(2015)', '(2017)', '(2004)', '(2016)', '(2006)', '(2014)', '(2012)', '(2018)', '(2011)', '(2017)', '(2008)', '(2018)', '(2017)', '(2015)', '(2012)', '(2012)', '(2017)', '(2010)', '(2007)', '(2012)', '(2010)', '(2014)', '(2005)', '(2012)', '(2014)', '(2015)', '(2016)', '(2005)', '(1995)', '(2018)', '(2013)', '(2015)', '(2009)', '(2008)', '(2015)', '(2017)', '(2018)', '(2014)', '(2018)', '(2010)', '(1876)', '(2017)', '(2016)', '(2013)', '(2014)', '(1981)', '(1997)', '(2018)', '(2011)', '(2016)', '(2018)', '(2008)', '(2008)', '(2015)', '(2016)', '(2012)', '(2012)', '(2016)', '(2015)', '(2014)', '(2015)', '(2015)', '(2008)', '(2015)', '(2012)', '(2014)', '(2016)', '(2018)', '(2014)
# ...

# %%
def clean_year(year_string):
    year1 = year_string.replace('(','')
    year2 = year1.replace(')','')
    year = year2
    return year

# %%
print(year)
# Out:
# ['(2017)', '(2015)', '(2016)', '(2015)', '(2018)', '(2017)', '(2005)', '(2016)', '(2017)', '(2016)', '(2016)', '(2012)', '(2017)', '(2012)', '(2011)', '(2015)', '(2017)', '(2013)', '(2007)', '(2015)', '(2016)', '(2002)', '(2016)', '(2011)', '(2014)', '(2019)', '(2013)', '(2015)', '(2007)', '(2016)', '(2015)', '(2015)', '(2017)', '(2004)', '(2016)', '(2006)', '(2014)', '(2012)', '(2018)', '(2011)', '(2017)', '(2008)', '(2018)', '(2017)', '(2015)', '(2012)', '(2012)', '(2017)', '(2010)', '(2007)', '(2012)', '(2010)', '(2014)', '(2005)', '(2012)', '(2014)', '(2015)', '(2016)', '(2005)', '(1995)', '(2018)', '(2013)', '(2015)', '(2009)', '(2008)', '(2015)', '(2017)', '(2018)', '(2014)', '(2018)', '(2010)', '(1876)', '(2017)', '(2016)', '(2013)', '(2014)', '(1981)', '(1997)', '(2018)', '(2011)', '(2016)', '(2018)', '(2008)', '(2008)', '(2015)', '(2016)', '(2012)', '(2012)', '(2016)', '(2015)', '(2014)', '(2015)', '(2015)', '(2008)', '(2015)', '(2012)', '(2014)', '(2016)', '(2018)', '(2014)
# ...

# %%
clean_year('clean_year("(2010)")((5435))')
# Out:
# '5435'

# %%
clean_year("(2010)")
# Out:
# '2010'

# %%
clean_year("(2010))))")
# Out:
# '2010'

# %%
clean_year("(()()()()20033434)")
# Out:
# '20033434'

# %%
def clean_year(year_string):
    year1 = year_string.replace('(','')
    year2 = year1.replace(')','')
    year = int(year2)
    return year

# %%
clean_year('(257)')
# Out:
# 257

# %%
year = clean_year(year_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-1b93677c50ab> in <module>
# ----> 1 year = clean_year(year_string)
#
# <ipython-input-73-f37ea752ed31> in clean_year(year_string)
#       1 def clean_year(year_string):
# ----> 2     year1 = year_string.replace('(','')
#       3     year2 = year1.replace(')','')
#       4     year = int(year2)
#       5     return year
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
def clean_year(year_string):
    return int(year_string.replace('(','').replace(')',''))

# %%
print(year_string)
# Out:
# ['(2017)', '(2015)', '(2016)', '(2015)', '(2018)', '(2017)', '(2005)', '(2016)', '(2017)', '(2016)', '(2016)', '(2012)', '(2017)', '(2012)', '(2011)', '(2015)', '(2017)', '(2013)', '(2007)', '(2015)', '(2016)', '(2002)', '(2016)', '(2011)', '(2014)', '(2019)', '(2013)', '(2015)', '(2007)', '(2016)', '(2015)', '(2015)', '(2017)', '(2004)', '(2016)', '(2006)', '(2014)', '(2012)', '(2018)', '(2011)', '(2017)', '(2008)', '(2018)', '(2017)', '(2015)', '(2012)', '(2012)', '(2017)', '(2010)', '(2007)', '(2012)', '(2010)', '(2014)', '(2005)', '(2012)', '(2014)', '(2015)', '(2016)', '(2005)', '(1995)', '(2018)', '(2013)', '(2015)', '(2009)', '(2008)', '(2015)', '(2017)', '(2018)', '(2014)', '(2018)', '(2010)', '(1876)', '(2017)', '(2016)', '(2013)', '(2014)', '(1981)', '(1997)', '(2018)', '(2011)', '(2016)', '(2018)', '(2008)', '(2008)', '(2015)', '(2016)', '(2012)', '(2012)', '(2016)', '(2015)', '(2014)', '(2015)', '(2015)', '(2008)', '(2015)', '(2012)', '(2014)', '(2016)', '(2018)', '(2014)
# ...

# %%
clean_year(year_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-e019bb3a54ea> in <module>
# ----> 1 clean_year(year_string)
#
# <ipython-input-78-c0cea95f21f9> in clean_year(year_string)
#       1 def clean_year(year_string):
# ----> 2     return int(year_string.replace('(','').replace(')',''))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
print(av)
# Out:
# ['\n\t\t\t8.85\t\t', '\n\t\t\t8.62\t\t', '\n\t\t\t8.42\t\t', '\n\t\t\t8.49\t\t', '\n\t\t\t8.63\t\t', '\n\t\t\t8.69\t\t', '\n\t\t\t8.31\t\t', '\n\t\t\t8.43\t\t', '\n\t\t\t8.50\t\t', '\n\t\t\t8.26\t\t', '\n\t\t\t8.28\t\t', '\n\t\t\t8.45\t\t', '\n\t\t\t8.32\t\t', '\n\t\t\t8.17\t\t', '\n\t\t\t8.13\t\t', '\n\t\t\t8.11\t\t', '\n\t\t\t8.35\t\t', '\n\t\t\t8.11\t\t', '\n\t\t\t8.15\t\t', '\n\t\t\t8.11\t\t', '\n\t\t\t8.19\t\t', '\n\t\t\t8.02\t\t', '\n\t\t\t8.18\t\t', '\n\t\t\t8.10\t\t', '\n\t\t\t8.08\t\t', '\n\t\t\t8.11\t\t', '\n\t\t\t8.05\t\t', '\n\t\t\t8.17\t\t', '\n\t\t\t7.97\t\t', '\n\t\t\t8.11\t\t', '\n\t\t\t8.00\t\t', '\n\t\t\t8.74\t\t', '\n\t\t\t8.20\t\t', '\n\t\t\t7.88\t\t', '\n\t\t\t8.09\t\t', '\n\t\t\t7.97\t\t', '\n\t\t\t8.05\t\t', '\n\t\t\t7.92\t\t', '\n\t\t\t8.06\t\t', '\n\t\t\t7.92\t\t', '\n\t\t\t7.87\t\t', '\n\t\t\t7.88\t\t', '\n\t\t\t8.49\t\t', '\n\t\t\t8.03\t\t', '\n\t\t\t7.92\t\t', '\n\t\t\t7.88\t\t', '\n\t\t\t7.88\t\t', '\n\t\t\t8.09\t\t', '\n\t\t\t7.77\t\t', '\n\t\t\t7.76\t\t
# ...

# %%
def clean_float(av_string):
    return float(av_string.replace('\n\t\t\t','').replace('\t\t',''))

# %%
def clean_float(av_string):
    return float(av_string.replace('\n','').replace('\t',''))

# %%
av = clean_float(av_string)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-8f70e5e39004> in <module>
# ----> 1 av = clean_float(av_string)
#
# <ipython-input-84-7740d74f9fdb> in clean_float(av_string)
#       1 def clean_float(av_string):
# ----> 2     return float(av_string.replace('\n','').replace('\t',''))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
av = clean_float(list(av_string))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-86-09b001bbb2a1> in <module>
# ----> 1 av = clean_float(list(av_string))
#
# <ipython-input-84-7740d74f9fdb> in clean_float(av_string)
#       1 def clean_float(av_string):
# ----> 2     return float(av_string.replace('\n','').replace('\t',''))
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
year = list(map(clean_year,year_string))

# %%
print(year)
# Out:
# [2017, 2015, 2016, 2015, 2018, 2017, 2005, 2016, 2017, 2016, 2016, 2012, 2017, 2012, 2011, 2015, 2017, 2013, 2007, 2015, 2016, 2002, 2016, 2011, 2014, 2019, 2013, 2015, 2007, 2016, 2015, 2015, 2017, 2004, 2016, 2006, 2014, 2012, 2018, 2011, 2017, 2008, 2018, 2017, 2015, 2012, 2012, 2017, 2010, 2007, 2012, 2010, 2014, 2005, 2012, 2014, 2015, 2016, 2005, 1995, 2018, 2013, 2015, 2009, 2008, 2015, 2017, 2018, 2014, 2018, 2010, 1876, 2017, 2016, 2013, 2014, 1981, 1997, 2018, 2011, 2016, 2018, 2008, 2008, 2015, 2016, 2012, 2012, 2016, 2015, 2014, 2015, 2015, 2008, 2015, 2012, 2014, 2016, 2018, 2014]

# %%
voters = list(map(clean_year,voters_string))

# %%
print(voters)
# Out:
# [31656, 34912, 48903, 18408, 10297, 9532, 36772, 19125, 12166, 46928, 23320, 11259, 16505, 35087, 40382, 47442, 12969, 23070, 16751, 21868, 21334, 58972, 13638, 25195, 18240, 21998, 25506, 11496, 59596, 19924, 28877, 6661, 9079, 52471, 12322, 17315, 18227, 26743, 14177, 24905, 38629, 24332, 6469, 11307, 17271, 29525, 25301, 8884, 74870, 42728, 17080, 16695, 6659, 25463, 41465, 28225, 7975, 21499, 17684, 22180, 12954, 25937, 9664, 28330, 31124, 57614, 5168, 8476, 38221, 8355, 16390, 10430, 3920, 7163, 13134, 23237, 14853, 23985, 10471, 13510, 6414, 5257, 71940, 90003, 11614, 7023, 14561, 21736, 7097, 21141, 35623, 9906, 10626, 40701, 6636, 20793, 16157, 7019, 11142, 31519]

# %%
av = list(map(clean_float,av_string))

# %%
print(av)
# Out:
# [8.85, 8.62, 8.42, 8.49, 8.63, 8.69, 8.31, 8.43, 8.5, 8.26, 8.28, 8.45, 8.32, 8.17, 8.13, 8.11, 8.35, 8.11, 8.15, 8.11, 8.19, 8.02, 8.18, 8.1, 8.08, 8.11, 8.05, 8.17, 7.97, 8.11, 8.0, 8.74, 8.2, 7.88, 8.09, 7.97, 8.05, 7.92, 8.06, 7.92, 7.87, 7.88, 8.49, 8.03, 7.92, 7.88, 7.88, 8.09, 7.77, 7.76, 7.84, 7.85, 8.1, 7.8, 7.76, 7.77, 8.02, 7.81, 7.86, 7.76, 7.94, 7.83, 7.91, 7.73, 7.74, 7.67, 8.18, 8.01, 7.69, 7.96, 7.76, 7.83, 8.48, 8.04, 7.79, 7.7, 7.77, 7.7, 7.86, 7.77, 8.06, 8.1, 7.63, 7.62, 7.81, 7.95, 7.73, 7.72, 7.89, 7.67, 7.63, 7.79, 7.78, 7.59, 7.96, 7.71, 7.69, 7.88, 7.76, 7.6]

# %%
geek = list(map(clean_float,geek_string))

# %%
print(geek)
# Out:
# [8.585, 8.471, 8.269, 8.236, 8.213, 8.174, 8.16, 8.156, 8.14, 8.098, 8.097, 8.064, 8.033, 8.021, 8.011, 7.979, 7.969, 7.945, 7.937, 7.922, 7.916, 7.901, 7.896, 7.891, 7.882, 7.881, 7.878, 7.869, 7.867, 7.855, 7.825, 7.818, 7.812, 7.786, 7.782, 7.773, 7.772, 7.77, 7.766, 7.748, 7.738, 7.737, 7.729, 7.723, 7.719, 7.714, 7.692, 7.684, 7.673, 7.662, 7.654, 7.648, 7.645, 7.641, 7.636, 7.628, 7.627, 7.621, 7.618, 7.612, 7.61, 7.606, 7.596, 7.592, 7.584, 7.581, 7.579, 7.578, 7.577, 7.576, 7.574, 7.572, 7.567, 7.56, 7.558, 7.556, 7.555, 7.548, 7.546, 7.545, 7.538, 7.534, 7.529, 7.526, 7.522, 7.511, 7.508, 7.508, 7.49, 7.487, 7.486, 7.485, 7.481, 7.48, 7.479, 7.475, 7.474, 7.47, 7.465, 7.462]

# %%
tabla = list(zip(name,year,geek,av,voters))

# %%
print(tabla)
# Out:
# [('Gloomhaven', 2017, 8.585, 8.85, 31656), ('Pandemic Legacy: Season 1', 2015, 8.471, 8.62, 34912), ('Terraforming Mars', 2016, 8.269, 8.42, 48903), ('Through the Ages: A New Story of Civilization', 2015, 8.236, 8.49, 18408), ('Brass: Birmingham', 2018, 8.213, 8.63, 10297), ('Twilight Imperium (Fourth Edition)', 2017, 8.174, 8.69, 9532), ('Twilight Struggle', 2005, 8.16, 8.31, 36772), ('Star Wars: Rebellion', 2016, 8.156, 8.43, 19125), ('Gaia Project', 2017, 8.14, 8.5, 12166), ('Scythe', 2016, 8.098, 8.26, 46928), ('Great Western Trail', 2016, 8.097, 8.28, 23320), ('War of the Ring (Second Edition)', 2012, 8.064, 8.45, 11259), ('Spirit Island', 2017, 8.033, 8.32, 16505), ('Terra Mystica', 2012, 8.021, 8.17, 35087), ('The Castles of Burgundy', 2011, 8.011, 8.13, 40382), ('7 Wonders Duel', 2015, 7.979, 8.11, 47442), ('The 7th Continent', 2017, 7.969, 8.35, 12969), ('Concordia', 2013, 7.945, 8.11, 23070), ('Brass: Lancashire', 2007, 7.937, 8.15, 16751), ('Viticulture Essential Edition',
# ...

# %%
import csv

# %%
with open('boardgames.csv', 'w', newline='') as myfile:
     wr = csv.writer(tabla, quoting=csv.QUOTE_ALL)
     wr.writerow(tabla)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-106-57553d909572> in <module>
#       1 with open('boardgames.csv', 'w', newline='') as myfile:
# ----> 2      wr = csv.writer(tabla, quoting=csv.QUOTE_ALL)
#       3      wr.writerow(tabla)
#
# TypeError: argument 1 must have a "write" method

# %%
with open('boardgames.csv', 'w', newline='') as myfile:
     writer(tabla, quoting=csv.QUOTE_ALL)
     writerow(tabla)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-107-89aa91c14796> in <module>
#       1 with open('boardgames.csv', 'w', newline='') as myfile:
# ----> 2      writer(tabla, quoting=csv.QUOTE_ALL)
#       3      writerow(tabla)
#
# NameError: name 'writer' is not defined

# %%
with open('boardgames.csv', 'w') as myfile:
     writer = csv.writer(myfile)
     writer.writerows(tabla)

# %%
import pandas as pd

# %%
data = pd.read_csv('boardgames.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-122-90046b84063d> in <module>
# ----> 1 data = pd.read_csv('boardgames.csv')
#       2 data.head()
#
# ...

# %%
import pandas as pd

juegos = pd.read_csv("boardgames.csv")
juegos.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe9 in position 3: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-123-c7807f8a43e8> in <module>
#       1 import pandas as pd
#       2
# ----> 3 juegos = pd.read_csv("boardgames.csv")
#       4 juegos.head()
#
# ...

# %%
os.chdir('C:\Users\Franco\Documentos\Python\Boardgames\Scrap')
# Out:
#   File "<ipython-input-1-8796412df2ef>", line 1
#     os.chdir('C:\Users\Franco\Documentos\Python\Boardgames\Scrap')
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
import os

# %%
os.chdir('C:\Users\Franco\Documentos\Python\Boardgames\Scrap')
# Out:
#   File "<ipython-input-3-8796412df2ef>", line 1
#     os.chdir('C:\Users\Franco\Documentos\Python\Boardgames\Scrap')
#             ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
print(os.getcwd())
# Out:
# C:\Users\Bruno

# %%
os.chdir(C:\Users\Franco\Documentos\Python\Boardgames\Scrap)
# Out:
#   File "<ipython-input-5-1ba62fc786a0>", line 1
#     os.chdir(C:\Users\Franco\Documentos\Python\Boardgames\Scrap)
#               ^
# SyntaxError: invalid syntax

# %%
os.chdir('C:\\Users\\Franco\\Documentos\\Python\\Boardgames\\Scrap')

# %%
print(os.getcwd())
# Out:
# C:\Users\Franco\Documentos\Python\Boardgames\Scrap
