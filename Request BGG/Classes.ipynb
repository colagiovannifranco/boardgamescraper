# %%
import pandas as pd
import requests
from io import StringIO 
from lxml import etree
import csv

# %%
class Downloader:
    
    def __init__(self, url):
        self.url = url
        self.html = ''
    
    def download_page(self):
        req = requests.get(self.url)
        self.html = req.text
        return

# %%
r = Downloader('https://boardgamegeek.com/browse/boardgame/page1')

# %%
r.download_page()

# %%
r.url
# Out:
# 'https://boardgamegeek.com/browse/boardgame/page1'

# %%
r.html
# Out:
# '\n<!DOCTYPE html>\n<html ng-app="GeekApp" lang="en-US" ng-cloak>\n<head>\n\t<meta charset=\'utf-8\'>\n\t<meta id="vp" name="viewport" content="width=device-width, initial-scale=1.0">\n\t\t\t<script>\n\t\t\twindow.addEventListener( \'DOMContentLoaded\',  function() {\n\t\t\t\tif (window.innerWidth < 960) {\n\t\t\t\t\tvar mvp = document.getElementById(\'vp\');\n\t\t\t\t\tmvp.setAttribute(\'content\',\'width=960\');\n\t\t\t\t}\n\t\t\t});\n\t\t</script>\n\t\t<meta content=\'yes\' name=\'apple-mobile-web-app-capable\'>\n\t<meta content=\'IE=edge,chrome=1\' http-equiv=\'X-UA-Compatible\'>\n\n\t\t\t<title>Browse Board Games | BoardGameGeek</title>\n\t\n\t\n<link rel="apple-touch-icon" \thref="https://cf.geekdo-static.com/icons/touch-icon180.png" />\n<link rel="shortcut icon" \t\thref="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />\n<link rel="icon" \t\t\t\t\thref="https://cf.geekdo-static.com/icons/favicon2.ico" type="image/ico" />\n<link rel="search" \t\t\t\thref="/game-opensearch.xml" type="application/opensearchdescription+xml" title="BGG Game Search" />\n<meta name="apple-mobile-web-app-title" content="BGG">\n\n\n\t<meta property="og:image" content="https://cf.geekdo-static.com/images/opengraph/bgg_opengraph.png" />\n\n\n\n\n\t<meta name="keywords" content="board game, boardgames, boardgame, board, games, game, hobby, boardgamegeek, geek, geekdo">\n\n\t\t\t\t\t\t<link rel=\'stylesheet\' type=\'text/css\' href=\'https://cf.geekdo-static.com/static/geekui_master2_5e334c383338b.css\'>\n\t\t\t\t\t<link rel=\'stylesheet\' type=\'text/css\' href=\'https://cf.geekdo-static.com/static/css_master2_5e334c373840b.css\'>\n\t\t\t\n\t<base href="/">\n\n\t\n<script>\n\tvar GEEK = GEEK || {};\n\tGEEK.adBlock = [];\n\tGEEK.adConfig = {"blockleaderboard":null,"blockskyscraper":null,"noadsense":true};\n\tGEEK.adSlots = {"dfp-leaderboard":{"name":"boardgame_leaderboard_728x90"},"dfp-skyscraper":{"name":"boardgame_skyscraper_160x600"},"dfp-medrect":{"name":"boardgame_rectangle_300x250"},"dfp-medrect-reserved-home":{"name":"boardgame_reserved_home_300x250"}};\n\tGEEK.googleTargets = null;\n\tGEEK.userid = 0;\n\tGEEK.domainname = \'boardgamegeek.com\';\n\tGEEK.domain = \'boardgame\';\n\tGEEK.geekitemPreload = {};\n\tGEEK.geekitemSettings = null;\n\tGEEK.geekitemModules = null;\n\tGEEK.geekGlobalSettings = {"shutdown_file_ops":"1","shutdown_storeimage_ops":"0","shutdown_edit_avatar":"0","shutdown_file_upload":"0","shutdown_file_download":"0","shutdown_image_upload":"0"};\n\tGEEK.geekimageSettings = null;\n\tGEEK.legacy = 1;\n\n\tGEEK.apiurlsPrefix = \'https://api.geekdo.com\';\n\t\tGEEK.apiurls = {\n\t\t\'amazon\': \'/api/amazon\',\n\t\t\'files\': \'/api/files\',\n\t\t\'geekitems\': \'/api/geekitems\',\n\t\t\'images\': \'/api/images\',\n\t\t\'threads\': \'/api/forums/threads\',\n\t \t\'forums\': \'/api/forums\',\n\t\t\'videos\': \'/api/videos\',\n\t\t\'hotness\': \'/api/hotness\',\n\t\t\'dynamicinfo\': \'/api/dynamicinfo\',\n\t\t\'subtypeinfo\': \'/api/subtypeinfo\',\n\t\t\'geekbay\': \'/api/geekbay\',\n\t\t\'geekmarket\': \'/geekmarket/api/v1\',\n\t    \'geekmarketapi\': \'/api/geekmarket\',\n\t\t\'geeklists\': \'/api/geeklists\',\n\t\t\'reviews\': \'/api/reviews\',\n\t\t\'collections\': \'/api/collections\',\n\t\t\'linkeditems\': \'/api/geekitem/linkeditems\',\n\t\t\'subscriptions\': \'/api/subscriptions\',\n\t    \'fans\': \'/api/fans\',\n\t    \'geekpreviews\': \'/api/geekpreviews\',\n\t    \'geekpreviewitems\': \'/api/geekpreviewitems\',\n\t   \t\'geekpreviewparentitems\': \'/api/geekpreviewparentitems\',\n\t\t\'recs\': \'/api/geekitem/recs\',\n\t    \'awards\': \'/api/geekawards\'\n\t};\n</script>\n\n\t\t\t\t\t\t\t<script type=\'text/javascript\' src=\'https://cf.geekdo-static.com/static/geekangular17_master2_5e334c392dff8.js\'></script>\n\t\t\t\t\t<script type=\'text/javascript\' src=\'https://cf.geekdo-static.com/static/geekui_master2_5e334c383338b.js\'></script>\n\t\t\t\t\t<script type=\'text/javascript\' src=\'https://cf ...

# %%
class Parser:
    
    xpath_celdas_nombre = "//table[@id='collectionitems']/tr/td[3]/div[2][contains(@id,'results_objectname')]"
    xpath_geek = "//table[@id='collectionitems']/tr/td[4]/text()"
    xpath_average = "//table[@id='collectionitems']/tr/td[5]/text()"
    xpath_voters = "//table[@id='collectionitems']/tr/td[6]/text()"
    
    def __init__(self, html):
        
        self.html = html
        self.tabla = []
        
        self.htmlparser = etree.HTMLParser()
        self.html_tree = etree.parse(StringIO(html), self.htmlparser)
                
    def clean_entero(self, string_entero):
        if "N/A" in string_entero:
            return
        else:
            return int(string_entero.replace('(','').replace(')',''))
    
    def clean_flotante(self, string_flotante):
        if "N/A" in string_flotante:
            return
        else: 
            return float(string_flotante.replace('\n','').replace('\t',''))
    
    def download_tabla(self):
        
        celdas_nombre = self.html_tree.xpath(self.xpath_celdas_nombre)

        name = []
        year_string = []
        
        for c in celdas_nombre:
            n = c.xpath("a/text()")
            name += n
            year = c.xpath("span/text()")
            if year:
                year_string += year
            else:
                year_string.append("N/A")

        geek_string = self.html_tree.xpath(self.xpath_geek)
        average_string = self.html_tree.xpath(self.xpath_average)
        voters_string = self.html_tree.xpath(self.xpath_voters)

        year = list(map(self.clean_entero,year_string))
        voters = list(map(self.clean_entero,voters_string))

        geek = list(map(self.clean_flotante,geek_string))
        average= list(map(self.clean_flotante,average_string))

        self.tabla = list(zip(name,year,geek,average,voters))
        return self.tabla

# %%
p = Parser(r.html)

# %%
p.download_tabla()
# Out:
# [('Gloomhaven', 2017, 8.582, 8.85, 31932),
#  ('Pandemic Legacy: Season 1', 2015, 8.47, 8.62, 35062),
#  ('Terraforming Mars', 2016, 8.268, 8.42, 49308),
#  ('Through the Ages: A New Story of Civilization', 2015, 8.234, 8.49, 18498),
#  ('Brass: Birmingham', 2018, 8.218, 8.63, 10468),
#  ('Twilight Imperium (Fourth Edition)', 2017, 8.175, 8.69, 9629),
#  ('Twilight Struggle', 2005, 8.16, 8.31, 36864),
#  ('Star Wars: Rebellion', 2016, 8.157, 8.43, 19225),
#  ('Gaia Project', 2017, 8.141, 8.5, 12262),
#  ('Great Western Trail', 2016, 8.097, 8.28, 23451),
#  ('Scythe', 2016, 8.097, 8.26, 47215),
#  ('War of the Ring (Second Edition)', 2012, 8.066, 8.45, 11327),
#  ('Spirit Island', 2017, 8.032, 8.32, 16691),
#  ('Terra Mystica', 2012, 8.02, 8.17, 35187),
#  ('The Castles of Burgundy', 2011, 8.011, 8.13, 40525),
#  ('7 Wonders Duel', 2015, 7.979, 8.11, 47723),
#  ('The 7th Continent', 2017, 7.967, 8.35, 13050),
#  ('Concordia', 2013, 7.946, 8.11, 23208),
#  ('Brass: Lancashire', 2007, 7.938, 8.15, 16806),
#  ('Viticulture Essential Edition', 2015, 7.921, 8.11, 22022),
#  ('Arkham Horror: The Card Game', 2016, 7.916, 8.19, 21481),
#  ('Puerto Rico', 2002, 7.901, 8.02, 59081),
#  ('A Feast for Odin', 2016, 7.895, 8.18, 13704),
#  ('Mage Knight Board Game', 2011, 7.89, 8.1, 25258),
#  ('Orléans', 2014, 7.882, 8.08, 18318),
#  ('Wingspan', 2019, 7.882, 8.11, 22541),
#  ('Caverna: The Cave Farmers', 2013, 7.878, 8.04, 25560),
#  ('Food Chain Magnate', 2015, 7.87, 8.18, 11563),
#  ('Agricola', 2007, 7.866, 7.97, 59686),
#  ('Mansions of Madness: Second Edition', 2016, 7.855, 8.11, 20060),
#  ('Blood Rage', 2015, 7.825, 8.01, 29026),
#  ('Kingdom Death: Monster', 2015, 7.818, 8.74, 6682),
#  ('Pandemic Legacy: Season 2', 2017, 7.812, 8.2, 9143),
#  ('Power Grid', 2004, 7.786, 7.88, 52570),
#  ('Mechs vs. Minions', 2016, 7.782, 8.09, 12364),
#  ('Star Wars: Imperial Assault', 2014, 7.772, 8.05, 18294),
#  ('Through the Ages: A Story of Civilization', 2006, 7.772, 7.97, 17326),
#  ("Tzolk'in: The Mayan Calendar", 2012, 7.77, 7.92, 26821),
#  ('Root', 2018, 7.767, 8.06, 14453),
#  ('Eclipse', 2011, 7.746, 7.92, 24940),
#  ('Le Havre', 2008, 7.737, 7.88, 24376),
#  ('Azul', 2017, 7.737, 7.87, 39016),
#  ('Nemesis', 2018, 7.732, 8.49, 6631),
#  ('Clans of Caledonia', 2017, 7.724, 8.03, 11383),
#  ('The Voyages of Marco Polo', 2015, 7.717, 7.92, 17335),
#  ('Robinson Crusoe: Adventures on the Cursed Island',
#   2012,
#   7.713,
#   7.88,
#   29610),
#  ('Android: Netrunner', 2012, 7.692, 7.88, 25334),
#  ('Anachrony', 2017, 7.684, 8.09, 8922),
#  ('7 Wonders', 2010, 7.672, 7.77, 75118),
#  ('Race for the Galaxy', 2007, 7.662, 7.76, 42792),
#  ('Keyflower', 2012, 7.654, 7.84, 17112),
#  ('Dominant Species', 2010, 7.648, 7.85, 16715),
#  ('Fields of Arle', 2014, 7.645, 8.1, 6682),
#  ('Caylus', 2005, 7.641, 7.8, 25498),
#  ('Lords of Waterdeep', 2012, 7.635, 7.76, 41577),
#  ('The Gallerist', 2015, 7.629, 8.02, 8018),
#  ('Five Tribes', 2014, 7.628, 7.77, 28336),
#  ('Clank!: A Deck-Building Adventure', 2016, 7.62, 7.81, 21634),
#  ('Twilight Imperium (Third Edition)', 2005, 7.617, 7.86, 17694),
#  ('El Grande', 1995, 7.611, 7.76, 22213),
#  ('Rising Sun', 2018, 7.608, 7.93, 13029),
#  ('Eldritch Horror', 2013, 7.605, 7.83, 26028),
#  ('Mombasa', 2015, 7.596, 7.91, 9703),
#  ('Dominion: Intrigue', 2009, 7.592, 7.73, 28365),
#  ('Everdell', 2018, 7.586, 8.01, 8785),
#  ('Battlestar Galactica: The Board Game', 2008, 7.583, 7.74, 31164),
#  ('Lisboa', 2017, 7.583, 8.18, 5210),
#  ('Codenames', 2015, 7.581, 7.67, 57867),
#  ('Teotihuacan: City of Gods', 2018, 7.578, 7.96, 8467),
#  ('Patchwork', 2014, 7.577, 7.68, 38411),
#  ('Crokinole', 1876, 7.574, 7.84, 10470),
#  ('Troyes', 2010, 7.574, 7.76, 16445),
#  ('Too Many Bones', 2017, 7.567, 8.47, 3966),
#  ("Aeon's End", 2016, 7.56, 8.03, 7231),
#  ('Russian Railroads', 2013, 7.558, 7.79, 13169),
#  ('Roll for the Galaxy', 2014, 7.554, 7.7, 23312),
#  ('Sherlock Holmes Consulting Detective: The Thames Murders & Other Cases',
#   1981,
#   7.554,
#   7.77,
#   14906),
#  ('Tigris & Euphrates', 1997, 7.548, 7.7, 24013),
#  ('Architects of the West Kingdom', 2018, 7.546, 7.86, 10648),
#  ('Trajan', 2011, 7.545, 7.78, 13532),
#  ('Underwater Cities', 2018, 7.542, 8.1, 5377),
#  ('Agricola (Revised Edition)', 2016, 7.54, 8.06, 6485),
#  ('Dominion', 2008, 7.529, 7.63, 72075),
#  ('Pandemic', 2008, 7.525, 7.62, 90277),
#  ('Raiders of the North Sea', 2015, 7.523, 7.8, 11722),
#  ('Pandemic: Iberia', 2016, 7.511, 7.95, 7060),
#  ('Kemet', 2012, 7.508, 7.73, 14619),
#  ('Star Wars: X-Wing Miniatures Game', 2012, 7.507, 7.72, 21776),
#  ('Yokohama', 2016, 7.491, 7.89, 7148),
#  ('Dead of Winter: A Crossroads Game', 2014, 7.484, 7.63, 35743),
#  ('Grand Austria Hotel', 2015, 7.484, 7.79, 9961),
#  ('T.I.M.E Stories', 2015, 7.483, 7.66, 21226),
#  ('Champions of Midgard', 2015, 7.483, 7.79, 10715),
#  ('Forbidden Stars', 2015, 7.48, 7.96, 6668),
#  ('Stone Age', 2008, 7.48, 7.59, 40779),
#  ('Descent: Journeys in the Dark (Second Edition)', 2012, 7.474, 7.71, 20846),
#  ('Alchemists', 2014, 7.473, 7.69, 16229),
#  ('Lorenzo il Magnifico', 2016, 7.471, 7.88, 7066),
#  ('The Quacks of Quedlinburg', 2018, 7.467, 7.76, 11437),
#  ('Star Realms', 2014, 7.462, 7.6, 31653)]

# %%
f = Downloader('https://boardgamegeek.com/browse/boardgame/page2')

# %%
def guardar_csv(tabla):
    with open('tabla_20200131.csv', 'w', encoding='utf-8') as myfile:
     writer = csv.writer(myfile)
     writer.writerow(['name', 'year', 'geek_rating','average_rating','voters'])
     writer.writerows(tabla)
    return

# %%
tabla_completa = []

for i in range(1, 1138):
    print(f'bajando pagina {i}')
    r = Downloader(f'https://boardgamegeek.com/browse/boardgame/page/{i}')
    r.download_page()
    p = Parser(r.html)
    p.download_tabla()
    tabla_completa += p.tabla

guardar_csv(tabla_completa)
# Out:
# bajando pagina 1
# bajando pagina 2
# bajando pagina 3
# bajando pagina 4
# bajando pagina 5
# bajando pagina 6
# bajando pagina 7
# bajando pagina 8
# bajando pagina 9
# bajando pagina 10
# bajando pagina 11
# bajando pagina 12
# bajando pagina 13
# bajando pagina 14
# bajando pagina 15
# bajando pagina 16
# bajando pagina 17
# bajando pagina 18
# bajando pagina 19
# bajando pagina 20
# bajando pagina 21
# bajando pagina 22
# bajando pagina 23
# bajando pagina 24
# bajando pagina 25
# bajando pagina 26
# bajando pagina 27
# bajando pagina 28
# bajando pagina 29
# bajando pagina 30
# bajando pagina 31
# bajando pagina 32
# bajando pagina 33
# bajando pagina 34
# bajando pagina 35
# bajando pagina 36
# bajando pagina 37
# bajando pagina 38
# bajando pagina 39
# bajando pagina 40
# bajando pagina 41
# bajando pagina 42
# bajando pagina 43
# bajando pagina 44
# bajando pagina 45
# bajando pagina 46
# bajando pagina 47
# bajando pagina 48
# bajando pagina 49
# bajando pagina 50
# bajando pagina 51
# bajando pagina 52
# bajando pagina 53
# bajando pagina 54
# bajando pagina 55
# bajando pagina 56
# bajando pagina 57
# bajando pagina 58
# bajando pagina 59
# bajando pagina 60
# bajando pagina 61
# bajando pagina 62
# bajando pagina 63
# bajando pagina 64
# bajando pagina 65
# bajando pagina 66
# bajando pagina 67
# bajando pagina 68
# bajando pagina 69
# bajando pagina 70
# bajando pagina 71
# bajando pagina 72
# bajando pagina 73
# bajando pagina 74
# bajando pagina 75
# bajando pagina 76
# bajando pagina 77
# bajando pagina 78
# bajando pagina 79
# bajando pagina 80
# bajando pagina 81
# bajando pagina 82
# bajando pagina 83
# bajando pagina 84
# bajando pagina 85
# bajando pagina 86
# bajando pagina 87
# bajando pagina 88
# bajando pagina 89
# bajando pagina 90
# bajando pagina 91
# bajando pagina 92
# bajando pagina 93
# bajando pagina 94
# bajando pagina 95
# bajando pagina 96
# bajando pagina 97
# bajando pagina 98
# bajando pagina 99
# bajando pagina 100
# bajando pagina 101
# bajando pagina 102
# bajando pagina 103
# bajando pagina 104
# bajando pagina 105
# bajando pagina 106
# bajando pagina 107
# bajando pagina 108
# bajando pagina 109
# bajando pagina 110
# bajando pagina 111
# bajando pagina 112
# bajando pagina 113
# bajando pagina 114
# bajando pagina 115
# bajando pagina 116
# bajando pagina 117
# bajando pagina 118
# bajando pagina 119
# bajando pagina 120
# bajando pagina 121
# bajando pagina 122
# bajando pagina 123
# bajando pagina 124
# bajando pagina 125
# bajando pagina 126
# bajando pagina 127
# bajando pagina 128
# bajando pagina 129
# bajando pagina 130
# bajando pagina 131
# bajando pagina 132
# bajando pagina 133
# bajando pagina 134
# bajando pagina 135
# bajando pagina 136
# bajando pagina 137
# bajando pagina 138
# bajando pagina 139
# bajando pagina 140
# bajando pagina 141
# bajando pagina 142
# bajando pagina 143
# bajando pagina 144
# bajando pagina 145
# bajando pagina 146
# bajando pagina 147
# bajando pagina 148
# bajando pagina 149
# bajando pagina 150
# bajando pagina 151
# bajando pagina 152
# bajando pagina 153
# bajando pagina 154
# bajando pagina 155
# bajando pagina 156
# bajando pagina 157
# bajando pagina 158
# bajando pagina 159
# bajando pagina 160
# bajando pagina 161
# bajando pagina 162
# bajando pagina 163
# bajando pagina 164
# bajando pagina 165
# bajando pagina 166
# bajando pagina 167
# bajando pagina 168
# bajando pagina 169
# bajando pagina 170
# bajando pagina 171
# bajando pagina 172
# bajando pagina 173
# bajando pagina 174
# bajando pagina 175
# bajando pagina 176
# bajando pagina 177
# bajando pagina 178
# bajando pagina 179
# bajando pagina 180
# bajando pagina 181
# bajando pagina 182
# bajando pagina 183
# bajando pagina 184
# bajando pagina 185
# bajando pagina 186
# bajando pagina 187
# bajando pagina 188
# bajando pagina 189
# bajando pagina 190
# bajando pagina 191
# bajando pagina 192
# bajando pagina 193
# bajando pagina 194
# bajando pagina 195
# bajando pagina 196
# bajando pagina 197
# bajando pagina 198
# bajando pagina 199
# bajando pagina 200
# bajando pagina 201
# bajando pagina 202
# bajando pagina 203
# bajando pagina 204
# bajando pagina 205
# bajando pagina 206
# bajando pagina 207
# bajando pagina 208
# bajando pagina 209
# bajando pagina 210
# bajando pagina 211
# bajando pagina 212
# bajando pagina 213
# bajando pagina 214
# bajando pagina 215
# bajando pagina 216
# bajando pagina 217
# bajando pagina 218
# bajando pagina 219
# bajando pagina 220
# bajando pagina 221
# bajando pagina 222
# bajando pagina 223
# bajando pagina 224
# bajando pagina 225
# bajando pagina 226
# bajando pagina 227
# bajando pagina 228
# bajando pagina 229
# bajando pagina 230
# bajando pagina 231
# bajando pagina 232
# bajando pagina 233
# bajando pagina 234
# bajando pagina 235
# bajando pagina 236
# bajando pagina 237
# bajando pagina 238
# bajando pagina 239
# bajando pagina 240
# bajando pagina 241
# bajando pagina 242
# bajando pagina 243
# bajando pagina 244
# bajando pagina 245
# bajando pagina 246
# bajando pagina 247
# bajando pagina 248
# bajando pagina 249
# bajando pagina 250
# bajando pagina 251
# bajando pagina 252
# bajando pagina 253
# bajando pagina 254
# bajando pagina 255
# bajando pagina 256
# bajando pagina 257
# bajando pagina 258
# bajando pagina 259
# bajando pagina 260
# bajando pagina 261
# bajando pagina 262
# bajando pagina 263
# bajando pagina 264
# bajando pagina 265
# bajando pagina 266
# bajando pagina 267
# bajando pagina 268
# bajando pagina 269
# bajando pagina 270
# bajando pagina 271
# bajando pagina 272
# bajando pagina 273
# bajando pagina 274
# bajando pagina 275
# bajando pagina 276
# bajando pagina 277
# bajando pagina 278
# bajando pagina 279
# bajando pagina 280
# bajando pagina 281
# bajando pagina 282
# bajando pagina 283
# bajando pagina 284
# bajando pagina 285
# bajando pagina 286
# bajando pagina 287
# bajando pagina 288
# bajando pagina 289
# bajando pagina 290
# bajando pagina 291
# bajando pagina 292
# bajando pagina 293
# bajando pagina 294
# bajando pagina 295
# bajando pagina 296
# bajando pagina 297
# bajando pagina 298
# bajando pagina 299
# bajando pagina 300
# bajando pagina 301
# bajando pagina 302
# bajando pagina 303
# bajando pagina 304
# bajando pagina 305
# bajando pagina 306
# bajando pagina 307
# bajando pagina 308
# bajando pagina 309
# bajando pagina 310
# bajando pagina 311
# bajando pagina 312
# bajando pagina 313
# bajando pagina 314
# bajando pagina 315
# bajando pagina 316
# bajando pagina 317
# bajando pagina 318
# bajando pagina 319
# bajando pagina 320
# bajando pagina 321
# bajando pagina 322
# bajando pagina 323
# bajando pagina 324
# bajando pagina 325
# bajando pagina 326
# bajando pagina 327
# bajando pagina 328
# bajando pagina 329
# bajando pagina 330
# bajando pagina 331
# bajando pagina 332
# bajando pagina 333
# bajando pagina 334
# bajando pagina 335
# bajando pagina 336
# bajando pagina 337
# bajando pagina 338
# bajando pagina 339
# bajando pagina 340
# bajando pagina 341
# bajando pagina 342
# bajando pagina 343
# bajando pagina 344
# bajando pagina 345
# bajando pagina 346
# bajando pagina 347
# bajando pagina 348
# bajando pagina 349
# bajando pagina 350
# bajando pagina 351
# bajando pagina 352
# bajando pagina 353
# bajando pagina 354
# bajando pagina 355
# bajando pagina 356
# bajando pagina 357
# bajando pagina 358
# bajando pagina 359
# bajando pagina 360
# bajando pagina 361
# bajando pagina 362
# bajando pagina 363
# bajando pagina 364
# bajando pagina 365
# bajando pagina 366
# bajando pagina 367
# bajando pagina 368
# bajando pagina 369
# bajando pagina 370
# bajando pagina 371
# bajando pagina 372
# bajando pagina 373
# bajando pagina 374
# bajando pagina 375
# bajando pagina 376
# bajando pagina 377
# bajando pagina 378
# bajando pagina 379
# bajando pagina 380
# bajando pagina 381
# bajando pagina 382
# bajando pagina 383
# bajando pagina 384
# bajando pagina 385
# bajando pagina 386
# bajando pagina 387
# bajando pagina 388
# bajando pagina 389
# bajando pagina 390
# bajando pagina 391
# bajando pagina 392
# bajando pagina 393
# bajando pagina 394
# bajando pagina 395
# bajando pagina 396
# bajando pagina 397
# bajando pagina 398
# bajando pagina 399
# bajando pagina 400
# bajando pagina 401
# bajando pagina 402
# bajando pagina 403
# bajando pagina 404
# bajando pagina 405
# bajando pagina 406
# bajando pagina 407
# bajando pagina 408
# bajando pagina 409
# bajando pagina 410
# bajando pagina 411
# bajando pagina 412
# bajando pagina 413
# bajando pagina 414
# bajando pagina 415
# bajando pagina 416
# bajando pagina 417
# bajando pagina 418
# bajando pagina 419
# bajando pagina 420
# bajando pagina 421
# bajando pagina 422
# bajando pagina 423
# bajando pagina 424
# bajando pagina 425
# bajando pagina 426
# bajando pagina 427
# bajando pagina 428
# bajando pagina 429
# bajando pagina 430
# bajando pagina 431
# bajando pagina 432
# bajando pagina 433
# bajando pagina 434
# bajando pagina 435
# bajando pagina 436
# bajando pagina 437
# bajando pagina 438
# bajando pagina 439
# bajando pagina 440
# bajando pagina 441
# bajando pagina 442
# bajando pagina 443
# bajando pagina 444
# bajando pagina 445
# bajando pagina 446
# bajando pagina 447
# bajando pagina 448
# bajando pagina 449
# bajando pagina 450
# bajando pagina 451
# bajando pagina 452
# bajando pagina 453
# bajando pagina 454
# bajando pagina 455
# bajando pagina 456
# bajando pagina 457
# bajando pagina 458
# bajando pagina 459
# bajando pagina 460
# bajando pagina 461
# bajando pagina 462
# bajando pagina 463
# bajando pagina 464
# bajando pagina 465
# bajando pagina 466
# bajando pagina 467
# bajando pagina 468
# bajando pagina 469
# bajando pagina 470
# bajando pagina 471
# bajando pagina 472
# bajando pagina 473
# bajando pagina 474
# bajando pagina 475
# bajando pagina 476
# bajando pagina 477
# bajando pagina 478
# bajando pagina 479
# bajando pagina 480
# bajando pagina 481
# bajando pagina 482
# bajando pagina 483
# bajando pagina 484
# bajando pagina 485
# bajando pagina 486
# bajando pagina 487
# bajando pagina 488
# bajando pagina 489
# bajando pagina 490
# bajando pagina 491
# bajando pagina 492
# bajando pagina 493
# bajando pagina 494
# bajando pagina 495
# bajando pagina 496
# bajando pagina 497
# bajando pagina 498
# bajando pagina 499
# bajando pagina 500
# bajando pagina 501
# bajando pagina 502
# bajando pagina 503
# bajando pagina 504
# bajando pagina 505
# bajando pagina 506
# bajando pagina 507
# bajando pagina 508
# bajando pagina 509
# bajando pagina 510
# bajando pagina 511
# bajando pagina 512
# bajando pagina 513
# bajando pagina 514
# bajando pagina 515
# bajando pagina 516
# bajando pagina 517
# bajando pagina 518
# bajando pagina 519
# bajando pagina 520
# bajando pagina 521
# bajando pagina 522
# bajando pagina 523
# bajando pagina 524
# bajando pagina 525
# bajando pagina 526
# bajando pagina 527
# bajando pagina 528
# bajando pagina 529
# bajando pagina 530
# bajando pagina 531
# bajando pagina 532
# bajando pagina 533
# bajando pagina 534
# bajando pagina 535
# bajando pagina 536
# bajando pagina 537
# bajando pagina 538
# bajando pagina 539
# bajando pagina 540
# bajando pagina 541
# bajando pagina 542
# bajando pagina 543
# bajando pagina 544
# bajando pagina 545
# bajando pagina 546
# bajando pagina 547
# bajando pagina 548
# bajando pagina 549
# bajando pagina 550
# bajando pagina 551
# bajando pagina 552
# bajando pagina 553
# bajando pagina 554
# bajando pagina 555
# bajando pagina 556
# bajando pagina 557
# bajando pagina 558
# bajando pagina 559
# bajando pagina 560
# bajando pagina 561
# bajando pagina 562
# bajando pagina 563
# bajando pagina 564
# bajando pagina 565
# bajando pagina 566
# bajando pagina 567
# bajando pagina 568
# bajando pagina 569
# bajando pagina 570
# bajando pagina 571
# bajando pagina 572
# bajando pagina 573
# bajando pagina 574
# bajando pagina 575
# bajando pagina 576
# bajando pagina 577
# bajando pagina 578
# bajando pagina 579
# bajando pagina 580
# bajando pagina 581
# bajando pagina 582
# bajando pagina 583
# bajando pagina 584
# bajando pagina 585
# bajando pagina 586
# bajando pagina 587
# bajando pagina 588
# bajando pagina 589
# bajando pagina 590
# bajando pagina 591
# bajando pagina 592
# bajando pagina 593
# bajando pagina 594
# bajando pagina 595
# bajando pagina 596
# bajando pagina 597
# bajando pagina 598
# bajando pagina 599
# bajando pagina 600
# bajando pagina 601
# bajando pagina 602
# bajando pagina 603
# bajando pagina 604
# bajando pagina 605
# bajando pagina 606
# bajando pagina 607
# bajando pagina 608
# bajando pagina 609
# bajando pagina 610
# bajando pagina 611
# bajando pagina 612
# bajando pagina 613
# bajando pagina 614
# bajando pagina 615
# bajando pagina 616
# bajando pagina 617
# bajando pagina 618
# bajando pagina 619
# bajando pagina 620
# bajando pagina 621
# bajando pagina 622
# bajando pagina 623
# bajando pagina 624
# bajando pagina 625
# bajando pagina 626
# bajando pagina 627
# bajando pagina 628
# bajando pagina 629
# bajando pagina 630
# bajando pagina 631
# bajando pagina 632
# bajando pagina 633
# bajando pagina 634
# bajando pagina 635
# bajando pagina 636
# bajando pagina 637
# bajando pagina 638
# bajando pagina 639
# bajando pagina 640
# bajando pagina 641
# bajando pagina 642
# bajando pagina 643
# bajando pagina 644
# bajando pagina 645
# bajando pagina 646
# bajando pagina 647
# bajando pagina 648
# bajando pagina 649
# bajando pagina 650
# bajando pagina 651
# bajando pagina 652
# bajando pagina 653
# bajando pagina 654
# bajando pagina 655
# bajando pagina 656
# bajando pagina 657
# bajando pagina 658
# bajando pagina 659
# bajando pagina 660
# bajando pagina 661
# bajando pagina 662
# bajando pagina 663
# bajando pagina 664
# bajando pagina 665
# bajando pagina 666
# bajando pagina 667
# bajando pagina 668
# bajando pagina 669
# bajando pagina 670
# bajando pagina 671
# bajando pagina 672
# bajando pagina 673
# bajando pagina 674
# bajando pagina 675
# bajando pagina 676
# bajando pagina 677
# bajando pagina 678
# bajando pagina 679
# bajando pagina 680
# bajando pagina 681
# bajando pagina 682
# bajando pagina 683
# bajando pagina 684
# bajando pagina 685
# bajando pagina 686
# bajando pagina 687
# bajando pagina 688
# bajando pagina 689
# bajando pagina 690
# bajando pagina 691
# bajando pagina 692
# bajando pagina 693
# bajando pagina 694
# bajando pagina 695
# bajando pagina 696
# bajando pagina 697
# bajando pagina 698
# bajando pagina 699
# bajando pagina 700
# bajando pagina 701
# bajando pagina 702
# bajando pagina 703
# bajando pagina 704
# bajando pagina 705
# bajando pagina 706
# bajando pagina 707
# bajando pagina 708
# bajando pagina 709
# bajando pagina 710
# bajando pagina 711
# bajando pagina 712
# bajando pagina 713
# bajando pagina 714
# bajando pagina 715
# bajando pagina 716
# bajando pagina 717
# bajando pagina 718
# bajando pagina 719
# bajando pagina 720
# bajando pagina 721
# bajando pagina 722
# bajando pagina 723
# bajando pagina 724
# bajando pagina 725
# bajando pagina 726
# bajando pagina 727
# bajando pagina 728
# bajando pagina 729
# bajando pagina 730
# bajando pagina 731
# bajando pagina 732
# bajando pagina 733
# bajando pagina 734
# bajando pagina 735
# bajando pagina 736
# bajando pagina 737
# bajando pagina 738
# bajando pagina 739
# bajando pagina 740
# bajando pagina 741
# bajando pagina 742
# bajando pagina 743
# bajando pagina 744
# bajando pagina 745
# bajando pagina 746
# bajando pagina 747
# bajando pagina 748
# bajando pagina 749
# bajando pagina 750
# bajando pagina 751
# bajando pagina 752
# bajando pagina 753
# bajando pagina 754
# bajando pagina 755
# bajando pagina 756
# bajando pagina 757
# bajando pagina 758
# bajando pagina 759
# bajando pagina 760
# bajando pagina 761
# bajando pagina 762
# bajando pagina 763
# bajando pagina 764
# bajando pagina 765
# bajando pagina 766
# bajando pagina 767
# bajando pagina 768
# bajando pagina 769
# bajando pagina 770
# bajando pagina 771
# bajando pagina 772
# bajando pagina 773
# bajando pagina 774
# bajando pagina 775
# bajando pagina 776
# bajando pagina 777
# bajando pagina 778
# bajando pagina 779
# bajando pagina 780
# bajando pagina 781
# bajando pagina 782
# bajando pagina 783
# bajando pagina 784
# bajando pagina 785
# bajando pagina 786
# bajando pagina 787
# bajando pagina 788
# bajando pagina 789
# bajando pagina 790
# bajando pagina 791
# bajando pagina 792
# bajando pagina 793
# bajando pagina 794
# bajando pagina 795
# bajando pagina 796
# bajando pagina 797
# bajando pagina 798
# bajando pagina 799
# bajando pagina 800
# bajando pagina 801
# bajando pagina 802
# bajando pagina 803
# bajando pagina 804
# bajando pagina 805
# bajando pagina 806
# bajando pagina 807
# bajando pagina 808
# bajando pagina 809
# bajando pagina 810
# bajando pagina 811
# bajando pagina 812
# bajando pagina 813
# bajando pagina 814
# bajando pagina 815
# bajando pagina 816
# bajando pagina 817
# bajando pagina 818
# bajando pagina 819
# bajando pagina 820
# bajando pagina 821
# bajando pagina 822
# bajando pagina 823
# bajando pagina 824
# bajando pagina 825
# bajando pagina 826
# bajando pagina 827
# bajando pagina 828
# bajando pagina 829
# bajando pagina 830
# bajando pagina 831
# bajando pagina 832
# bajando pagina 833
# bajando pagina 834
# bajando pagina 835
# bajando pagina 836
# bajando pagina 837
# bajando pagina 838
# bajando pagina 839
# bajando pagina 840
# bajando pagina 841
# bajando pagina 842
# bajando pagina 843
# bajando pagina 844
# bajando pagina 845
# bajando pagina 846
# bajando pagina 847
# bajando pagina 848
# bajando pagina 849
# bajando pagina 850
# bajando pagina 851
# bajando pagina 852
# bajando pagina 853
# bajando pagina 854
# bajando pagina 855
# bajando pagina 856
# bajando pagina 857
# bajando pagina 858
# bajando pagina 859
# bajando pagina 860
# bajando pagina 861
# bajando pagina 862
# bajando pagina 863
# bajando pagina 864
# bajando pagina 865
# bajando pagina 866
# bajando pagina 867
# bajando pagina 868
# bajando pagina 869
# bajando pagina 870
# bajando pagina 871
# bajando pagina 872
# bajando pagina 873
# bajando pagina 874
# bajando pagina 875
# bajando pagina 876
# bajando pagina 877
# bajando pagina 878
# bajando pagina 879
# bajando pagina 880
# bajando pagina 881
# bajando pagina 882
# bajando pagina 883
# bajando pagina 884
# bajando pagina 885
# bajando pagina 886
# bajando pagina 887
# bajando pagina 888
# bajando pagina 889
# bajando pagina 890
# bajando pagina 891
# bajando pagina 892
# bajando pagina 893
# bajando pagina 894
# bajando pagina 895
# bajando pagina 896
# bajando pagina 897
# bajando pagina 898
# bajando pagina 899
# bajando pagina 900
# bajando pagina 901
# bajando pagina 902
# bajando pagina 903
# bajando pagina 904
# bajando pagina 905
# bajando pagina 906
# bajando pagina 907
# bajando pagina 908
# bajando pagina 909
# bajando pagina 910
# bajando pagina 911
# bajando pagina 912
# bajando pagina 913
# bajando pagina 914
# bajando pagina 915
# bajando pagina 916
# bajando pagina 917
# bajando pagina 918
# bajando pagina 919
# bajando pagina 920
# bajando pagina 921
# bajando pagina 922
# bajando pagina 923
# bajando pagina 924
# bajando pagina 925
# bajando pagina 926
# bajando pagina 927
# bajando pagina 928
# bajando pagina 929
# bajando pagina 930
# bajando pagina 931
# bajando pagina 932
# bajando pagina 933
# bajando pagina 934
# bajando pagina 935
# bajando pagina 936
# bajando pagina 937
# bajando pagina 938
# bajando pagina 939
# bajando pagina 940
# bajando pagina 941
# bajando pagina 942
# bajando pagina 943
# bajando pagina 944
# bajando pagina 945
# bajando pagina 946
# bajando pagina 947
# bajando pagina 948
# bajando pagina 949
# bajando pagina 950
# bajando pagina 951
# bajando pagina 952
# bajando pagina 953
# bajando pagina 954
# bajando pagina 955
# bajando pagina 956
# bajando pagina 957
# bajando pagina 958
# bajando pagina 959
# bajando pagina 960
# bajando pagina 961
# bajando pagina 962
# bajando pagina 963
# bajando pagina 964
# bajando pagina 965
# bajando pagina 966
# bajando pagina 967
# bajando pagina 968
# bajando pagina 969
# bajando pagina 970
# bajando pagina 971
# bajando pagina 972
# bajando pagina 973
# bajando pagina 974
# bajando pagina 975
# bajando pagina 976
# bajando pagina 977
# bajando pagina 978
# bajando pagina 979
# bajando pagina 980
# bajando pagina 981
# bajando pagina 982
# bajando pagina 983
# bajando pagina 984
# bajando pagina 985
# bajando pagina 986
# bajando pagina 987
# bajando pagina 988
# bajando pagina 989
# bajando pagina 990
# bajando pagina 991
# bajando pagina 992
# bajando pagina 993
# bajando pagina 994
# bajando pagina 995
# bajando pagina 996
# bajando pagina 997
# bajando pagina 998
# bajando pagina 999
# bajando pagina 1000
# bajando pagina 1001
# bajando pagina 1002
# bajando pagina 1003
# bajando pagina 1004
# bajando pagina 1005
# bajando pagina 1006
# bajando pagina 1007
# bajando pagina 1008
# bajando pagina 1009
# bajando pagina 1010
# bajando pagina 1011
# bajando pagina 1012
# bajando pagina 1013
# bajando pagina 1014
# bajando pagina 1015
# bajando pagina 1016
# bajando pagina 1017
# bajando pagina 1018
# bajando pagina 1019
# bajando pagina 1020
# bajando pagina 1021
# bajando pagina 1022
# bajando pagina 1023
# bajando pagina 1024
# bajando pagina 1025
# bajando pagina 1026
# bajando pagina 1027
# bajando pagina 1028
# bajando pagina 1029
# bajando pagina 1030
# bajando pagina 1031
# bajando pagina 1032
# bajando pagina 1033
# bajando pagina 1034
# bajando pagina 1035
# bajando pagina 1036
# bajando pagina 1037
# bajando pagina 1038
# bajando pagina 1039
# bajando pagina 1040
# bajando pagina 1041
# bajando pagina 1042
# bajando pagina 1043
# bajando pagina 1044
# bajando pagina 1045
# bajando pagina 1046
# bajando pagina 1047
# bajando pagina 1048
# bajando pagina 1049
# bajando pagina 1050
# bajando pagina 1051
# bajando pagina 1052
# bajando pagina 1053
# bajando pagina 1054
# bajando pagina 1055
# bajando pagina 1056
# bajando pagina 1057
# bajando pagina 1058
# bajando pagina 1059
# bajando pagina 1060
# bajando pagina 1061
# bajando pagina 1062
# bajando pagina 1063
# bajando pagina 1064
# bajando pagina 1065
# bajando pagina 1066
# bajando pagina 1067
# bajando pagina 1068
# bajando pagina 1069
# bajando pagina 1070
# bajando pagina 1071
# bajando pagina 1072
# bajando pagina 1073
# bajando pagina 1074
# bajando pagina 1075
# bajando pagina 1076
# bajando pagina 1077
# bajando pagina 1078
# bajando pagina 1079
# bajando pagina 1080
# bajando pagina 1081
# bajando pagina 1082
# bajando pagina 1083
# bajando pagina 1084
# bajando pagina 1085
# bajando pagina 1086
# bajando pagina 1087
# bajando pagina 1088
# bajando pagina 1089
# bajando pagina 1090
# bajando pagina 1091
# bajando pagina 1092
# bajando pagina 1093
# bajando pagina 1094
# bajando pagina 1095
# bajando pagina 1096
# bajando pagina 1097
# bajando pagina 1098
# bajando pagina 1099
# bajando pagina 1100
# bajando pagina 1101
# bajando pagina 1102
# bajando pagina 1103
# bajando pagina 1104
# bajando pagina 1105
# bajando pagina 1106
# bajando pagina 1107
# bajando pagina 1108
# bajando pagina 1109
# bajando pagina 1110
# bajando pagina 1111
# bajando pagina 1112
# bajando pagina 1113
# bajando pagina 1114
# bajando pagina 1115
# bajando pagina 1116
# bajando pagina 1117
# bajando pagina 1118
# bajando pagina 1119
# bajando pagina 1120
# bajando pagina 1121
# bajando pagina 1122
# bajando pagina 1123
# bajando pagina 1124
# bajando pagina 1125
# bajando pagina 1126
# bajando pagina 1127
# bajando pagina 1128
# bajando pagina 1129
# bajando pagina 1130
# bajando pagina 1131
# bajando pagina 1132
# bajando pagina 1133
# bajando pagina 1134
# bajando pagina 1135
# bajando pagina 1136
# bajando pagina 1137

# %%
juegos = pd.read_csv('tabla_20200131.csv', encoding = "ISO-8859-1")
juegos.head()
# Out:
#                                             name    year  geek_rating  \
# 0                                     Gloomhaven  2017.0        8.582
# 1                      Pandemic Legacy: Season 1  2015.0        8.470
# 2                              Terraforming Mars  2016.0        8.268
# 3  Through the Ages: A New Story of Civilization  2015.0        8.234
# 4                              Brass: Birmingham  2018.0        8.218
#
#    average_rating   voters
# 0            8.85  31932.0
# 1            8.62  35062.0
# 2            8.42  49308.0
# 3            8.49  18498.0
# 4            8.63  10468.0

# %%
type(r)
# Out:
# __main__.Downloader

# %%
isinstance(1, int)
# Out:
# True

# %%
isinstance("abv", float)
# Out:
# False

# %%
isinstance(r, Downloader)
# Out:
# True

# %%
p.xpath_celdas_nombre
# Out:
# "//table[@id='collectionitems']/tr/td[3]/div[2][contains(@id,'results_objectname')]"

# %%
p.htmlparser

# %%
p.html_tree
